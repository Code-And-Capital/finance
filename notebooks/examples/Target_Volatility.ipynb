# %% [markdown]
# ## Target Volatility

# %%
import sys
import os

sys.path.append(
    os.path.abspath(
        os.path.join(os.path.dirname(os.path.realpath("__file__")), "..", "..")
    )
)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Create Fake Index Data

# %%
names = ["foo", "bar", "rf"]
dates = pd.date_range(
    start="2015-01-01", end="2018-12-31", freq=pd.tseries.offsets.BDay()
)
n = len(dates)
rdf = pd.DataFrame(np.zeros((n, len(names))), index=dates, columns=names)

np.random.seed(1)
rdf["foo"] = np.random.normal(loc=0.1 / 252, scale=0.2 / np.sqrt(252), size=n)
rdf["bar"] = np.random.normal(loc=0.04 / 252, scale=0.05 / np.sqrt(252), size=n)
rdf["rf"] = 0.0

pdf = 100 * np.cumprod(1 + rdf)
pdf.plot();

# %% [markdown]
# ### Build Strategy

# %%
from bt.algos.flow import RunWeekly
from bt.algos.selection import SelectThese
from bt.algos.weighting import WeighInvVol, TargetVol
from bt.algos.portfolio_ops import Rebalance
from bt.core.strategy import Strategy
from bt.engine import Backtest
import bt

# %%
# algo to fire on the beginning of every week and to run on the first date
runWeeklyAlgo = RunWeekly(run_on_first_date=True)

selectTheseAlgo = SelectThese(["foo", "bar"])

# algo to set the weights to 1/vol contributions from each asset
#  with data over the last 12 months excluding yesterday
weighInvVolAlgo = WeighInvVol(
    lookback=pd.DateOffset(months=12), lag=pd.DateOffset(days=1)
)

# algo to set overall volatility of the portfolio to an annualized 10%
targetVolAlgo = TargetVol(
    0.1,
    lookback=pd.DateOffset(months=12),
    lag=pd.DateOffset(days=1),
    covar_method="standard",
    annualization_factor=252,
)


# algo to rebalance the current weights to weights set in target.temp
rebalAlgo = Rebalance()

# a strategy that rebalances monthly to specified weights
strat = Strategy(
    "static",
    [runWeeklyAlgo, selectTheseAlgo, weighInvVolAlgo, targetVolAlgo, rebalAlgo],
)

# %% [markdown]
# ### Run Backtest
#
# Note: The logic of the strategy is seperate from the data used in the backtest.

# %%
# set integer_positions=False when positions are not required to be integers(round numbers)
backtest = Backtest(strat, pdf, integer_positions=False)

res = bt.run(backtest)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]/Users/timbastian/Documents/Code & Capital/CODE_AND_CAPITAL/bt/algos/weighting/inv_vol.py:133: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   returns = price_window.pct_change().iloc[1:]
# /Users/timbastian/Documents/Code & Capital/CODE_AND_CAPITAL/bt/algos/weighting/target_vol.py:78: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   returns = price_window.pct_change().iloc[1:]
# /Users/timbastian/anaconda3/envs/codecapital/lib/python3.10/site-packages/numpy/lib/_function_base_impl.py:552: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# /Users/timbastian/anaconda3/envs/codecapital/lib/python3.10/site-packages/numpy/_core/_methods.py:137: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
# /Users/timbastian/anaconda3/envs/codecapital/lib/python3.10/site-packages/pandas/core/frame.py:11211: RuntimeWarning: Degrees of freedom <= 0 for slice
#   base_cov = np.cov(mat.T, ddof=ddof)
# /Users/timbastian/anaconda3/envs/codecapital/lib/python3.10/site-packages/numpy/lib/_function_base_impl.py:2894: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /Users/timbastian/anaconda3/envs/codecapital/lib/python3.10/site-packages/numpy/lib/_function_base_impl.py:2894: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# 100%|██████████| 1/1 [00:00<00:00,  1.49it/s]

# %% [markdown]
# You can see the realized volatility below is close to the targeted 10% volatility.

# %%
fig, ax = plt.subplots(nrows=1, ncols=1)
(res.prices.pct_change().rolling(window=12 * 20).std() * np.sqrt(252)).plot(ax=ax)
ax.set_title("Rolling Volatility")
ax.plot();

# %% [markdown]
# Because we are using a 1/vol allocation bar, the less risky security, has a much smaller weight.

# %%
fig, ax = plt.subplots(nrows=1, ncols=1)
res.get_security_weights().plot(ax=ax)
ax.set_title("Weights")
ax.plot();

# %% [markdown]
# If we plot the total risk contribution of each asset class and divide by the total volatility, then we can see that both asset's contribute roughly similar amounts of volatility.

# %%
weights = res.get_security_weights()
rolling_cov = (
    pdf.loc[:, weights.columns].pct_change().rolling(window=12 * 20).cov() * 252
)


trc = pd.DataFrame(np.nan, index=weights.index, columns=weights.columns)
for dt in pdf.index:
    trc.loc[dt, :] = (
        weights.loc[dt, :].values
        * rolling_cov.loc[dt, :].values
        @ weights.loc[dt, :].values
        / np.sqrt(
            weights.loc[dt, :].values
            @ rolling_cov.loc[dt, :].values
            @ weights.loc[dt, :].values
        )
    )


fig, ax = plt.subplots(nrows=1, ncols=1)
trc.plot(ax=ax)
ax.set_title("% Total Risk Contribution")
ax.plot();
